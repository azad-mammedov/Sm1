# %% [markdown]
# <a href="https://colab.research.google.com/github/azad-mammedov/Sm1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df=pd.read_csv("/content/time_series_covid19_confirmed_global.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
covid_df.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/13/22  \
# 0        0        0        0        0        0        0  ...   176201
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Columns: 795 entries, Province/State to 3/22/22
# dtypes: float64(2), int64(791), object(2)
# memory usage: 1.7+ MB

# %%
covid_df.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  282.000000  282.000000  284.000000  284.000000  284.000000  284.000000
# mean    20.106368   21.958718    1.961268    2.313380    3.323944    5.059859
# std     25.841453   75.893366   26.402603   26.499491   32.992032   45.919425
# min    -71.949900 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      4.643279  -22.036550    0.000000    0.000000    0.000000    0.000000
# 50%     21.607878   20.921188    0.000000    0.000000    0.000000    0.000000
# 75%     40.950592   84.992575    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20     1/27/20      1/28/20      1/29/20  ...       3/13/22  \
# count   284.000000   284.00000   284.000000   284.000000  ...  2.840000e+02
# mean      7.464789    10.31338    19.647887    21.721831  ...  1.613916e+06
# ...

# %%
covid_df_last_week_columns =covid_df.iloc[:,-8:].columns.to_list()
covid_df_last_week_by_countries = covid_df.iloc[:,[1]+[*range(-8,0,1)]]
covid_df_last_week_by_countries.sort_values(by=covid_df_last_week_columns,ascending=False,inplace=True)
covid_df_last_week_by_countries.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      Country/Region   3/15/22   3/16/22   3/17/22   3/18/22   3/19/22  \
# 256              US  79585838  79630853  79683737  79717247  79728165
# 148           India  42998938  43001477  43004005  43006080  43007841
# 31           Brazil  29441039  29488777  29532810  29584800  29624435
# 131          France  22995380  23101166  23201324  23297675  23395779
# 273  United Kingdom  19820181  19911155  20001627  20093762  20093762
# 135         Germany  17732946  18027870  18325720  18585957  18717682
# 218          Russia  17160872  17196841  17231013  17264828  17297181
# 255          Turkey  14600683  14623028  14644382  14663508  14680836
# ...

# %%
last_ten_data=covid_df_last_week_by_countries.head(10)

# %%
plt.figure(figsize = (15,8))
sns.boxplot(data=last_ten_data,x='Country/Region',y="3/15/22")
